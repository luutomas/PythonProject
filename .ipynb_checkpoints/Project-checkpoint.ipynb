# %%
import numpy as np
import pandas as pd 
import requests
from bs4 import BeautifulSoup
import pandas as pd
import tqdm as tqdm
from lxml import html
import time

# %%
def getSoup_test(link):
        r = requests.get(link)
        r.encoding = 'UTF-8'
        return BeautifulSoup(r.text, 'html')

# %%
bf_test = getSoup_test('https://www.bezrealitky.cz/nemovitosti-byty-domy/595733-nabidka-prodej-bytu')

# %%
bf_table = bf_test.find('div',{'data-element':"detail-description"}).find('table')

# %%
table_extract = [i.text.strip() for i in bf_table.findAll('tr')]
table_extract
# Out:
# ['Internet:\n\nZjistěte rychlost O2 internetu u vás doma.',
#  'Číslo inzerátu:\n595733',
#  'Dispozice:\n3+kk',
#  'Plocha:\n96 m²',
#  'Cena:\n7.590.000 Kč\n\nChci hypotéku\n\ni',
#  'Město:\nPraha',
#  'Městská část:\nZličín',
#  'Typ vlastnictví:\nOsobní',
#  'Typ budovy:\nCihla',
#  'Vybavenost:\nVybavený\nChci vybavit s Bonami',
#  'Podlaží:\n5',
#  'Balkón:\nAno',
#  'Terasa:\nNe',
#  'Výtah:\nNe',
#  'Garáž:\nNe',
#  'K dispozici od:\nIhned']

# %%
data_frame = pd.DataFrame(table_extract)

# %%
data_frame_recon = data_frame[0].str.split("\n", expand = True)
df = pd.DataFrame(data_frame_recon[[0,1]])
df.columns = ['metric', 'value']
df = df.set_index('metric')
df
# Out:
#                          value
# metric
# Internet:
# Číslo inzerátu:         595733
# Dispozice:                3+kk
# Plocha:                  96 m²
# Cena:             7.590.000 Kč
# Město:                   Praha
# Městská část:           Zličín
# Typ vlastnictví:        Osobní
# Typ budovy:              Cihla
# Vybavenost:           Vybavený
# Podlaží:                     5
# Balkón:                    Ano
# Terasa:                     Ne
# Výtah:                      Ne
# Garáž:                      Ne
# K dispozici od:          Ihned

# %%
bf_map = bf_test.find('div',{'id':"map"})
x = bf_map.find('iframe')['src'].find('q=') + 2
y = bf_map.find('iframe')['src'].find('&key')
location = bf_map.find('iframe')['src'][x:y]
print(location)
str_test = location.split(',')
str_test[0]
# Out:
# 50.0568199,14.2850438
# '50.0568199'

# %%
loc_dict = {"lat" : [str_test[0]], "long": [str_test[1]]}
loc_dict
loc_df = pd.DataFrame.from_dict(loc_dict, orient = 'index', columns = ['value'])
df_upd = pd.concat([df, loc_df])
df_upd
# Out:
#                          value
# Internet:
# Číslo inzerátu:         595733
# Dispozice:                3+kk
# Plocha:                  96 m²
# Cena:             7.590.000 Kč
# Město:                   Praha
# Městská část:           Zličín
# Typ vlastnictví:        Osobní
# Typ budovy:              Cihla
# Vybavenost:           Vybavený
# Podlaží:                     5
# Balkón:                    Ano
# Terasa:                     Ne
# Výtah:                      Ne
# Garáž:                      Ne
# K dispozici od:          Ihned
# lat                 50.0568199
# long                14.2850438

# %%
class HouseForSale: 
    '''
    Getting infos from webpage 
    '''
    def __init__(self, link):
        '''
        Input link to search Books appered in 
        '''
        self.link = link

    def getSoup(self):
        r = requests.get(self.link)
        r.encoding = 'UTF-8'
        return BeautifulSoup(r.text, 'html')
    
    def getParameters(self):
        bf = self.getSoup()
        bf_table = bf.find('div',{'data-element':"detail-description"}).find('table')
        table_extract = [i.text.strip() for i in bf_table.findAll('tr')]
        df_table = pd.DataFrame(table_extract)
        df_table_split = df_table[0].str.split("\n", expand = True)
        df = pd.DataFrame(df_table_split[[0,1]])
        df.columns = ['metric', 'value']
        df = df.set_index('metric')
        return df
    
    def getMap(self):
        bf = self.getSoup()
        bf_map = bf.find('div',{'id':"map"})
        x = bf_map.find('iframe')['src'].find('q=') + 2
        y = bf_map.find('iframe')['src'].find('&key')
        location = bf_map.find('iframe')['src'][x:y]
        loc_str = location.split(',')
        loc_dict = {"lat" : [loc_str[0]], "long": [loc_str[1]]}
        loc_df = pd.DataFrame.from_dict(loc_dict, orient = 'index', columns = ['value'])
        return loc_df
    
    def getDf(self):
        df_par = self.getParameters()
        df_map = self.getMap()
        df = pd.concat([df_par, df_map])
        return df

# %%
HouseForSale('https://www.bezrealitky.cz/nemovitosti-byty-domy/595733-nabidka-prodej-bytu').getDf()
# Out:
#                          value
# Internet:
# Číslo inzerátu:         595733
# Dispozice:                3+kk
# Plocha:                  96 m²
# Cena:             7.590.000 Kč
# Město:                   Praha
# Městská část:           Zličín
# Typ vlastnictví:        Osobní
# Typ budovy:              Cihla
# Vybavenost:           Vybavený
# Podlaží:                     5
# Balkón:                    Ano
# Terasa:                     Ne
# Výtah:                      Ne
# Garáž:                      Ne
# K dispozici od:          Ihned
# lat                 50.0568199
# long                14.2850438

# %% [markdown]
# # Downloader class
# - Manual test
# - defining class
#
# ## Manual test

# %%
def getLinks_test(link):
    
    page = requests.get(link)
    if page.status_code == requests.codes.ok:
        wp = getSoup_test(link)
        base_url = 'https://www.bezrealitky.cz'
        links = wp.findAll('div', {'product__body'})
        return [base_url + equity.find('a')['href'] for equity in links]

    next_page_text = wp.find('ul', class_="pagination justify-content-md-end").findAll('li')[-1].text

    if next_page_text == 'Další >':
        next_page_partial = wp.find('ul', class_="pagination justify-content-md-end").findAll('li')[-1].find('a')['href']
        next_page_url = base_url + next_page_partial
        links = wp.findAll('div', {'product__body'})
        return [base_url + equity.find('a')['href'] for equity in links]
    # No more 'Next' pages, finish the script
    else:
        print('Done')

# %%
l = "https://www.bezrealitky.cz/vypis/nabidka-prodej/byt/praha?_token=qNLlM7SSvDXIFrdOKHnbj0gv_-OMf7vw6yUc_-ILcFo"
getLinks_test(l)
# Out:
# ['https://www.bezrealitky.cz/nemovitosti-byty-domy/597004-nabidka-prodej-bytu-nazovska',
#  'https://www.bezrealitky.cz/nemovitosti-byty-domy/525867-nabidka-prodej-bytu-vorarska-hlavni-mesto-praha',
#  'https://www.bezrealitky.cz/nemovitosti-byty-domy/604082-nabidka-prodej-bytu-halkova-praha',
#  'https://www.bezrealitky.cz/nemovitosti-byty-domy/603415-nabidka-prodej-bytu-harmonicka-praha',
#  'https://www.bezrealitky.cz/nemovitosti-byty-domy/593293-nabidka-prodej-bytu-balbinova-prague',
#  'https://www.bezrealitky.cz/nemovitosti-byty-domy/598734-nabidka-prodej-bytu-praha-stodulky',
#  'https://www.bezrealitky.cz/nemovitosti-byty-domy/604073-nabidka-prodej-bytu-tupolevova-letnany',
#  'https://www.bezrealitky.cz/nemovitosti-byty-domy/603526-nabidka-prodej-bytu-molakova-praha',
#  'https://www.bezrealitky.cz/nemovitosti-byty-domy/593125-nabidka-prodej-bytu-bolonska-praha',
#  'https://www.bezrealitky.cz/nemovitosti-byty-domy/604227-nabidka-prodej-bytu-ke-kamyku-praha']

# %% [markdown]
# ## Defining class
# Manual test working - Downloader_single() working
# Pagination - Downloader_multi() work in progress

# %%
Downloader(l)

# %%
class Downloader_single:
    '''
    Download all links real estate to initiate
    '''
    def __init__(self, link):
        '''
        Give link to extract links of given webpages
        '''
        self.link = link
    
    def getSoup(self):
        r = requests.get(self.link)
        r.encoding = 'UTF-8'
        return BeautifulSoup(r.text, 'lxml')

    def getLinks(self):
        page = requests.get(self.link)
        if page.status_code == requests.codes.ok:
            wp = self.getSoup()
            base_url = 'https://www.bezrealitky.cz'
            links = wp.findAll('div', {'product__body'})
            return [base_url + equity.find('a')['href'] for equity in links]
    
    def getDataFrame(self):
        links = self.getLinks()
        name_list = [BookTaker(i).getName() for i in links]
        books_list = [BookTaker(i).getBooks() for i in links]
        return pd.DataFrame({"Character":name_list, "Books":books_list})

# %%
class Downloader_multi:
    '''
    Download all links real estate to initiate
    '''
    def __init__(self, link):
        '''
        Give link to extract links of given webpages
        '''
        self.link = link
    
    def getSoup(self):
        r = requests.get(self.link)
        r.encoding = 'UTF-8'
        return BeautifulSoup(r.text, 'lxml')

    def getLinks(self):
        page = requests.get(self.link)
        if page.status_code == requests.codes.ok:
            wp = self.getSoup()
            base_url = 'https://www.bezrealitky.cz'
            links = wp.findAll('div', {'product__body'})
            return [base_url + equity.find('a')['href'] for equity in links]
        
        next_page_text = wp.find('ul', class_="pagination justify-content-md-end").findAll('li')[-1].text
        
        if next_page_text == 'Další >':
            next_page_partial = wp.find('ul', class_="pagination justify-content-md-end").findAll('li')[-1].find('a')['href']
            next_page_url = base_url + next_page_partial
            getLinks(next_page_url)
        # No more 'Next' pages, finish the script
        else:
            print('Done')

# %% [markdown]
# ## Tutorial for pagination
# link - https://letslearnabout.net/python/beautiful-soup/how-to-get-the-next-page-on-beautiful-soup/#next-page

# %%
def parse_page(next_url):
    # HTTP GET requests
  page = requests.get(next_url)

  # Checking if we successfully fetched the URL
  if page.status_code == requests.codes.ok:
    bs = BeautifulSoup(page.text, 'lxml')

    check_no_results = bs.find('ul', class_="SearchResults").find('p')
    if check_no_results and check_no_results.text:
        print('Search returned no results.')
        return None

    # Fetching all items
    list_all_cd = bs.findAll('li', class_='ResultItem')

    
    for cd in list_all_cd:
      get_cd_attributes(cd)

    next_page_text = bs.find('ul', class_="SearchBreadcrumbs").findAll('li')[-1].text
    
    if next_page_text == 'Next':
        next_page_partial = bs.find('ul', class_="SearchBreadcrumbs").findAll(
            'li')[-1].find('a')['href']
        next_page_url = base_url + next_page_partial
        print(next_page_url)
        parse_page(next_page_url)
    # No more 'Next' pages, finish the script
    else:
        export_table_and_print(data)

parse_page(search_url)

# %%
class Downloader:
    '''
    Download all links for bookchecker to initiate
    '''
    def __init__(self, link):
        '''
        Give link to extract links of given webpages
        '''
        self.link = link
    
    def getSoup(self):
        r = requests.get(self.link)
        r.encoding = 'UTF-8'
        return BeautifulSoup(r.text, 'lxml')

    def getLinks(self):
        wp = self.getSoup()
        links = wp.find('span',{'id':'Unseen_University_and_the_Wizards'}).parent.previous.previous.parent.parent.parent.find_all('li')
        return ['http://wiki.lspace.org' + li.find('a')['href'] for li in links]

    def getDataFrame(self):
        links = self.getLinks()
        name_list = [BookTaker(i).getName() for i in links]
        books_list = [BookTaker(i).getBooks() for i in links]
        return pd.DataFrame({"Character":name_list, "Books":books_list})
